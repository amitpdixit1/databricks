# %%
# %sql
CREATE TABLE IF NOT EXISTS sample_employee (
  id INT,
  name STRING,
  dept STRING,
  salary INT
);
INSERT INTO sample_employee (id, name, dept, salary) VALUES
  (1, 'Alice', 'HR', 50000),
  (2, 'Bob', 'IT', 60000),
  (3, 'Charlie', 'Finance', 55000),
  (4, 'David', 'IT', 60000),
  (5, 'Eve', 'HR', 70000),
  (6, 'Alice', 'HR', 50000),  -- duplicate
  (7, 'Zara', 'Marketing', 65000, 'oops');

  update  sample_employee set extra_col = 'oops' where id = 7

# %% [markdown]
# hiii

# %%
display changes

# %%
df=df.explain()

# %%
fgdd
